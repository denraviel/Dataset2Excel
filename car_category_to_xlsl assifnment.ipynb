# %%
import pandas as pd
from pandas  import ExcelWriter

# %% [markdown]
# # Reading the vehicle Trade csv file

# %%
csvv_df = pd.read_csv("vehicle_trade_data.csv")

# %%
csvv_df
# Out:
#        public_reference   mileage reg_code standard_colour  standard_make  \
# 0       202010014440649   31534.0       17            Grey           MINI
# 1       202010155026725   52023.0       66            Blue     Volkswagen
# 2       202008142485309   29500.0       12            Grey  Mercedes-Benz
# 3       202009183894045   35300.0       18            Grey       Vauxhall
# 4       202010014441671   47299.0       65           Black         Nissan
# ...                 ...       ...      ...             ...            ...
# 96264   202010295556637   28225.0       17           White  Mercedes-Benz
# 96265   202010305614799  122000.0       07          Silver            BMW
# 96266   202010315639231   45000.0       15          Silver       Vauxhall
# 96267   202010315647416    4075.0       69            Grey         Nissan
# 96268   202010315659271   52760.0       62           White         Nissan
#
#       standard_model vehicle_condition  year_of_registration  price  \
# ...

# %% [markdown]
# # Filter standard make with respect to car Brands

# %%
a=csvv_df[csvv_df["standard_make"]=="Mercedes-Benz"]
a
# Out:
#        public_reference  mileage reg_code standard_colour  standard_make  \
# 2       202008142485309  29500.0       12            Grey  Mercedes-Benz
# 15      202008252922747  54000.0       15           White  Mercedes-Benz
# 18      202008313128882  29062.0       66            Grey  Mercedes-Benz
# 27      202009173839578  20729.0       17          Silver  Mercedes-Benz
# 33      202009244147952  28411.0       19           Black  Mercedes-Benz
# ...                 ...      ...      ...             ...            ...
# 96251   202010225326060  90000.0       53          Silver  Mercedes-Benz
# 96254   202010235370666  15713.0       68            Grey  Mercedes-Benz
# 96260   202010285515611  50000.0       63           Black  Mercedes-Benz
# 96262   202010285527271  22153.0       18            Blue  Mercedes-Benz
# 96264   202010295556637  28225.0       17           White  Mercedes-Benz
#
#       standard_model vehicle_condition  year_of_registration  price  \
# ...

# %%
b=csvv_df[csvv_df["standard_make"]=="Volkswagen"]
b
# Out:
#        public_reference   mileage reg_code standard_colour standard_make  \
# 1       202010155026725   52023.0       66            Blue    Volkswagen
# 7       202002137274498   35000.0       64           Black    Volkswagen
# 9       202006260546963   64785.0       61          Silver    Volkswagen
# 13      202008152524052    4290.0       20            Blue    Volkswagen
# 14      202008192669061  121000.0       10           Black    Volkswagen
# ...                 ...       ...      ...             ...           ...
# 96220   202009274280181  115000.0       60            Blue    Volkswagen
# 96224   202009304418482   69278.0       13          Silver    Volkswagen
# 96229   202010074712714   14395.0       17           White    Volkswagen
# 96247   202010205239879   83172.0       63            Grey    Volkswagen
# 96253   202010235346303   17482.0       19            Grey    Volkswagen
#
#       standard_model vehicle_condition  year_of_registration  price  \
# ...

# %%
c=csvv_df[csvv_df["standard_make"]=="Vauxhall"]
c
# Out:
#        public_reference   mileage reg_code standard_colour standard_make  \
# 3       202009183894045   35300.0       18            Grey      Vauxhall
# 6       202010155027121   17020.0       17            Grey      Vauxhall
# 8       202006150161276   61760.0       09          Silver      Vauxhall
# 10      202006290651340  117420.0       61          Silver      Vauxhall
# 12      202008112332443   17499.0       18           White      Vauxhall
# ...                 ...       ...      ...             ...           ...
# 96245   202010205228822   12584.0       19            Grey      Vauxhall
# 96248   202010215279274   58000.0       10           Black      Vauxhall
# 96258   202010265445023  108000.0       60          Silver      Vauxhall
# 96263   202010285546060   44000.0       64          Silver      Vauxhall
# 96266   202010315639231   45000.0       15          Silver      Vauxhall
#
#       standard_model vehicle_condition  year_of_registration  price  \
# ...

# %%
d=csvv_df[csvv_df["standard_make"]=="Nissan"]
d
# Out:
#        public_reference  mileage reg_code standard_colour standard_make  \
# 4       202010014441671  47299.0       65           Black        Nissan
# 20      202009073432201  30678.0       67           Black        Nissan
# 31      202009234083878  22764.0       17            Blue        Nissan
# 39      202009304410540  10000.0       68          Silver        Nissan
# 44      202010064647216     10.0       70           White        Nissan
# ...                 ...      ...      ...             ...           ...
# 96243   202010195177111   7456.0       69            Blue        Nissan
# 96249   202010225292123  44900.0       15           Black        Nissan
# 96259   202010275480505  93000.0       61           Black        Nissan
# 96267   202010315647416   4075.0       69            Grey        Nissan
# 96268   202010315659271  52760.0       62           White        Nissan
#
#       standard_model vehicle_condition  year_of_registration  price  \
# ...

# %%
e=csvv_df[csvv_df["standard_make"]=="Audi"]
e
# Out:
#        public_reference  mileage reg_code standard_colour standard_make  \
# 11      202007101093756  47000.0       16           Black          Audi
# 16      202008262959989  33000.0       66          Silver          Audi
# 49      202010074711401  33847.0       18           Black          Audi
# 55      202010124894836  41227.0       15            Blue          Audi
# 60      202010165061794  63262.0       13           White          Audi
# ...                 ...      ...      ...             ...           ...
# 96183   202010295558613  21604.0       18           White          Audi
# 96204   202008272977926  32874.0       16           White          Audi
# 96206   202009043316458  39894.0       66           Black          Audi
# 96212   202009224061193  21400.0       65            Grey          Audi
# 96237   202010144989694   6515.0       19           White          Audi
#
#       standard_model vehicle_condition  year_of_registration  price  \
# ...

# %%
f=csvv_df[csvv_df["standard_make"]=="MINI"]
f
# Out:
#        public_reference  mileage reg_code standard_colour standard_make  \
# 0       202010014440649  31534.0       17            Grey          MINI
# 23      202009133687405  52618.0       67            Grey          MINI
# 43      202010054613232   5937.0       17          Silver          MINI
# 80      202007091057229  11035.0       65           Black          MINI
# 101     202009153776857  40000.0       56           Black          MINI
# ...                 ...      ...      ...             ...           ...
# 96133   202009244143795   7764.0       16            Blue          MINI
# 96147   202010054618935  12005.0       68           White          MINI
# 96154   202010074732961  46500.0       10           Black          MINI
# 96161   202010165094511  27000.0       16           Black          MINI
# 96221   202009294358595  10460.0       69          Silver          MINI
#
#       standard_model vehicle_condition  year_of_registration  price  \
# ...

# %%
g=csvv_df[csvv_df["standard_make"]=="Kia"]
g
# Out:
#        public_reference  mileage reg_code standard_colour standard_make  \
# 50      202010074726490  55520.0       64           White           Kia
# 58      202010155054549  33670.0       66           White           Kia
# 98      202009103546522   9582.0       19          Silver           Kia
# 104     202009224067937  34837.0       17           Black           Kia
# 109     202010024509255  67000.0       64          Silver           Kia
# ...                 ...      ...      ...             ...           ...
# 96145   202010044587339  75094.0       67           White           Kia
# 96148   202010064648480  26321.0       19           Black           Kia
# 96156   202010104847418  19028.0       67            Grey           Kia
# 96172   202010235331457  43000.0       65           White           Kia
# 96200   202008072194972  21022.0       17           White           Kia
#
#       standard_model vehicle_condition  year_of_registration  price body_type  \
# ...

# %%
h=csvv_df[csvv_df["standard_make"]=="Renault"]
h
# Out:
#        public_reference  mileage reg_code standard_colour standard_make  \
# 17      202008262968969  30228.0       16           White       Renault
# 29      202009224036334  84000.0       58           Black       Renault
# 40      202010024508937   9003.0       67           White       Renault
# 57      202010134958350  58472.0       63            Blue       Renault
# 68      202010245396323  86500.0       08           Black       Renault
# ...                 ...      ...      ...             ...           ...
# 96137   202009304401157  49000.0       14            Blue       Renault
# 96159   202010134950296  43272.0       61           White       Renault
# 96175   202010235368048  89000.0       07            Blue       Renault
# 96236   202010124924270  67000.0       62           White       Renault
# 96252   202010235340603  77000.0       07           Black       Renault
#
#       standard_model vehicle_condition  year_of_registration  price  \
# ...

# %%
i=csvv_df[csvv_df["standard_make"]=="Fiat"]
i
# Out:
#        public_reference   mileage reg_code standard_colour standard_make  \
# 25      202009173835338   32479.0       66            Blue          Fiat
# 151     202010285534251   43000.0       13           White          Fiat
# 158     202002287827835   30144.0       13           White          Fiat
# 203     202010094796657   67450.0       13           White          Fiat
# 223     202010245375344   34924.0       59           White          Fiat
# ...                 ...       ...      ...             ...           ...
# 96169   202010215252316   35111.0       64            Blue          Fiat
# 96170   202010215256008  100000.0       59            Grey          Fiat
# 96210   202009183900694   45000.0       63           White          Fiat
# 96222   202009294365355   24000.0       65           Black          Fiat
# 96256   202010245401488   33356.0       17           White          Fiat
#
#       standard_model vehicle_condition  year_of_registration  price  \
# ...

# %%
j=csvv_df[csvv_df["standard_make"]=="Toyota"]
j
# Out:
#        public_reference   mileage reg_code standard_colour standard_make  \
# 5       202010235355785    7990.0       19           Black        Toyota
# 72      202010285535376    6506.0       68            Blue        Toyota
# 177     202009173855614   15250.0       68            Grey        Toyota
# 379     202010265459337    8020.0       19            Grey        Toyota
# 382     202010285525838   12023.0       66            Blue        Toyota
# ...                 ...       ...      ...             ...           ...
# 95824   202010155047604    2450.0       69            Grey        Toyota
# 95877   202009214013367   11409.0       67           Black        Toyota
# 96007   202010205233970  161000.0       10           Black        Toyota
# 96166   202010195182595    3918.0       20            Grey        Toyota
# 96189   202011015664903  120000.0       55          Silver        Toyota
#
#       standard_model vehicle_condition  year_of_registration  price  \
# ...

# %%
k=csvv_df[csvv_df["standard_make"]=="BMW"]
k
# Out:
#        public_reference   mileage reg_code standard_colour standard_make  \
# 19      202009033282749   14000.0       18           Black           BMW
# 21      202009093495711   25287.0       67          Silver           BMW
# 22      202009123632076  102498.0       15           Black           BMW
# 28      202009183920571   62000.0       66            Blue           BMW
# 35      202009284293085    9066.0       69            Blue           BMW
# ...                 ...       ...      ...             ...           ...
# 96250   202010225317647   29337.0       16            Blue           BMW
# 96255   202010245397920  131980.0       08           Black           BMW
# 96257   202010255424987   40000.0       62           Black           BMW
# 96261   202010285515718  100000.0       59          Silver           BMW
# 96265   202010305614799  122000.0       07          Silver           BMW
#
#       standard_model vehicle_condition  year_of_registration  price  \
# ...

# %% [markdown]
# # Writing into Excel diffrent sheets

# %%
writer = pd.ExcelWriter("car_category_multiple_to_Excel.xlsx")
a.to_excel(writer, sheet_name= "sheet1")
b.to_excel(writer, sheet_name= "sheet2")
c.to_excel(writer, sheet_name= "sheet3")
d.to_excel(writer, sheet_name= "sheet4")
e.to_excel(writer, sheet_name= "sheet5")
f.to_excel(writer, sheet_name= "sheet6")
g.to_excel(writer, sheet_name= "sheet7")
h.to_excel(writer, sheet_name= "sheet8")
i.to_excel(writer, sheet_name= "sheet9")
j.to_excel(writer, sheet_name= "sheet10")
k.to_excel(writer, sheet_name= "sheet11")
writer.save()
